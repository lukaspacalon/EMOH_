# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.tokenize import sent_tokenize
from colorama import Fore

def check_sentiment(text):
    sia = SentimentIntensityAnalyzer()
    sentences = sent_tokenize(text)
    
    for sentence in sentences:
        sentiment_scores = sia.polarity_scores(sentence)
        if sentiment_scores['compound'] >= 0:
            print(Fore.BLUE + sentence)
        else:
            print(Fore.RED + sentence)

# Exemple d'utilisation
texte = """
[18:53, 18/06/2023] Taïmé: Elle est trop bien cette photo !!
[19:12, 18/06/2023] Mireille Pacalon: 😄
[23:09, 18/06/2023] Mireille Pacalon: https://music.youtube.com/watch?v=FYGTT7YhywA&feature=share
[23:09, 18/06/2023] Mireille Pacalon: Payo Daddy cool ?
[23:10, 18/06/2023] Mireille Pacalon: Bonne fête aux Daddy !
[23:21, 18/06/2023] Jean PAYO PACALON 2: Merci bonne nuit paisible à tous daddy
[23:23, 18/06/2023] Mireille Pacalon: 🫶
[07:13, 19/06/2023] Jean PAYO PACALON 2: C'est 1 groupe d'information  féministe de rue qui parle aux passants des violences faites aux 🚺
[13:04, 20/06/2023] Jean PAYO PACALON 2: Lukipu as tu l'adresse exacte de ton 33m2 dans le 12ème (c'est grand en EST-OUEST, le 12ème !
[13:05, 20/06/2023] Jean PAYO PACALON 2: Loukiou )
[13:24, 20/06/2023] Lukas: Je sais pas exactement aha
[13:26, 20/06/2023] Lukas: Metro Dausmenil je crois
[13:51, 20/06/2023] Jean PAYO PACALON 2: OK  OK, il faudra que tu me dises la date de ton déménagement avec une carriole  De Mike il nous faut le volume de ce que tu transportes
[14:01, 20/06/2023] Lukas: Je te redis l'adresse exacte !
[14:01, 20/06/2023] Jean PAYO PACALON 2: Ok
[14:01, 20/06/2023] Lukas: La date de mon déménagement c'est le 10 Juillet dernier délai
[14:02, 20/06/2023] Lukas: Apres cette date je ne paye plus a Massy
[14:02, 20/06/2023] Lukas: Mais nous allons emménager le 1er juillet
[14:02, 20/06/2023] Lukas: Ce qui nous laisse une fenêtre de 10 jours pour le déménagement
[14:03, 20/06/2023] Lukas: On va déterminer la meilleur date mais ça sera sûrement un weekend
[14:03, 20/06/2023] Lukas: Je vais également faire une liste pour te fournir le volume de ce que je dois transporter.
[14:13, 20/06/2023] Jean PAYO PACALON 2: Le WE du 1-2 juillet semble pas mal ...
[14:16, 20/06/2023] Jean PAYO PACALON 2: Tu dois compter avec l'état des lieux + nettoyage du local sortant 1 fois vide et état des lieux du local entrant ET nettoyage AVANT d'entrer ... c'est bien
D'avoir 10j en effet
[14:16, 20/06/2023] Jean PAYO PACALON 2: Daumesnil = sympa
[14:22, 20/06/2023] Jean PAYO PACALON 2: RDV Dr BONNEL SEBASTIEN jeudi 08 juin 2023 ,236,rue VAUGIRARD Paris
Xxx  rdv.segur@gmail.com
Début :2 ORTHOPTISTES DIFFERENTES 
vue :  2 10 iéme à G  et 10 10ème 
TIO G/D 6/13 
Me reçoit ... "Quelle est Votre histoire ( ...) vous êtes ORL n'est-ce pas ?
.résumé en 5 mots de mon histoire :"" Chir Nordmann etc ... post opératoire avec chute A. VISUELLE post opératoire / ... ce matin TIO = 6/14
[16:04, 20/06/2023] Jean PAYO PACALON 2: Ah oui c'est ce que pensais.
1 sd de lésions du nerf optique associé à un angle de la chambre antérieure ouvert MAIS 1 PIO ou TIO pression intraoculaire NORMALE et non pas élevée ou moyenne
[16:10, 20/06/2023] Jean PAYO PACALON 2: Ce message bien sûr m'intéresse au + haut point  ...!!!
[16:16, 20/06/2023] Jody: Je peux tenter de me mettre à jour dans ce qu'il se fait en 2023 au niveau de cette pathologie
[16:17, 20/06/2023] Jean PAYO PACALON 2: YesSss
[16:55, 20/06/2023] Jody: https://we.tl/t-AIfq9mmjTj
[16:55, 20/06/2023] Jody: Lien pour télécharger une vidéo faite par un plongeur lors de notre stage, qui fait sa thèse sur la faune marine
[16:56, 20/06/2023] Jody: ça pèse 700 Mo par contre fichier lourd, plutot à ouvrir sur un pc qu'un portable
[16:56, 20/06/2023] Jody: *tél portable
[16:56, 20/06/2023] Jean PAYO PACALON 2: OK merci je regarderai ce soir ...
[08:37, 21/06/2023] Jody: Mounette on a fixé la date de l'état des lieux de l'appartement le 21 juillet à 10h
[08:37, 21/06/2023] Jody: Ca me laisse 10 jours pour revenir à besançon et préparer le départ a Copenhague.
[08:47, 21/06/2023] Jody: Par contre ils me demandent de faire visiter le logement, à leur place, alors que je rends l'appartement 10 jours avt en payant le mois complet. Alors que lorsque je suis entré dans l'appartement, c'était eux qui ont fait la visite
[09:07, 21/06/2023] Mireille Pacalon: Tu n'es pas obligé de le faire !
[09:08, 21/06/2023] Mireille Pacalon: Surtout si tu n'es pas présent
[09:09, 21/06/2023] Mireille Pacalon: Donc l'appartement doit être vidé à cette date
[09:10, 21/06/2023] Mireille Pacalon: On se parle ce soir pour fixer les choses
[09:23, 21/06/2023] Jody: J'ai appelé la nana, elle s'est a moitié offusquée. Elle m'as dit que je peux rendre l'appartement le 21 et payer au proratas, ce que je ne savais pas
[09:24, 21/06/2023] Jody: J'ai regardé le bail et en fait y'a aucune durée marquée qui m'obligerai de faire des visites
[09:25, 21/06/2023] Jody: Mais si je fais qqes visites et que je part plus tôt, je gagne environ 200 balles donc je vais faire ça si possible
[09:56, 21/06/2023] Mireille Pacalon: Ha bein oui
[09:56, 21/06/2023] Jody: Elle m'as dit que je devais faire des visites dés le début du préavis
[09:56, 21/06/2023] Jody: Ce qui est faux
[09:57, 21/06/2023] Mireille Pacalon: Car Lukas part le 10 juillet et ne paye pas le mois entier
[09:58, 21/06/2023] Mireille Pacalon: Je sais qu'effectivement on peut être amené à recevoir des gens pendant le préavis
[09:59, 21/06/2023] Mireille Pacalon: Comment tu le sais ?
[09:59, 21/06/2023] Mireille Pacalon: Je vais regarder
[09:59, 21/06/2023] Jody: Bah dans le bail y'a rien de spécifié explicitement
[10:00, 21/06/2023] Jody: Y'a pas de nombre de visites minimales
[10:00, 21/06/2023] Mireille Pacalon: Oui mais je crois qu'il a quand même une obligation....je m'informe
[10:05, 21/06/2023] Mireille Pacalon: Apparemment tu as raison il n'y a pas d'obligations mais du coup ils peuvent t'emmerder à l'état des lieux
# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

def detecter_emotion(texte):
    sia = SentimentIntensityAnalyzer()
    phrases = nltk.sent_tokenize(texte)  # Diviser le texte en phrases
    
    for phrase in phrases:
        polarite = sia.polarity_scores(phrase)
        
        if polarite['compound'] >= 0.5:
            emotion = "\033[93m"  # Affichage en jaune pour la joie
        elif polarite['compound'] <= -0.5:
            emotion = "\033[94m"  # Affichage en bleu pour la tristesse
        elif polarite['compound'] > -0.5 and polarite['compound'] < 0.5:
            if polarite['neg'] > polarite['pos']:
                emotion = "\033[91m"  # Affichage en rouge pour la colère
            elif polarite['neg'] > polarite['neu']:
                emotion = "\033[95m"  # Affichage en violet pour la peur
            else:
                emotion = "\033[92m"  # Affichage en vert pour le neutre
        
        print(f"{emotion}{phrase}\033[0m")


# Exemple d'utilisation
texte = """
Character A: Hello, how are you today?
Character B: It's going pretty well, I'm happy to see you!
Character A: Great, I'm glad to hear that. By the way, I have news to tell you!
Character B: Really? I'm curious, tell me everything!
Character A: I've been accepted into my dream college!
Character B: Wow, congratulations! I'm so proud of you, that's great news!
Character A: Thank you! I am really excited and full of enthusiasm for this new adventure.
Character B: I understand you, it must be a mixture of excitement and nervousness at the same time.
Character A: Yes, exactly! I have so many things to prepare and organize.
Character B: Don't worry, you are capable of meeting this challenge. I will be there to support you every step of the way.
Character A: Thank you, it's comforting to know that I have your support.
Character B: Of course, we are friends and I will be there to encourage you and help you when needed.
Character A: It's really great to be able to count on you. You are a true friend.
Character B: Thank you, that means a lot to me. Friendship is a precious emotion.
Character A: Absolutely, I'm grateful to have someone like you in my life.
Character B: Me too, we shared so many moments of joy, sadness and other emotions.
Character A: It's true, our friendship has gone through a wide range of emotions and it is all the stronger for it.
Character B: Exactly, that's what makes our bond so special. And I look forward to sharing new moments together.
Character A: Me too, the future looks bright with you by my side.
Character B: Let's go, live each moment with intensity and savor these precious emotions of life.

Character A: Hello, how are you today?
Character B: It's going pretty well, I'm happy to see you!
Character A: Great, I'm glad to hear that. By the way, I have news to tell you!
Character B: Really? I'm curious, tell me everything!
Character A: I've been accepted to my dream college!
Character B: Wow, congratulations! I'm so proud of you, that's great news!
Character A: Thank you! I am really excited and full of enthusiasm for this new adventure.
Character B: I understand you, it must be a mixture of excitement and nervousness at the same time.
Character A: Yes, exactly! I have so many things to prepare and organize.
Character B: Don't worry, you are capable of meeting this challenge. I will be there to support you every step of the way.
Character A: Thank you, it's comforting to know that I have your support.
Character B: Of course, we are friends and I will be there to encourage you and help you when needed.
Character A: It's really great to be able to count on you. You are a true friend.
Character B: Thank you, that means a lot to me. Friendship is a precious emotion.
Character A: Absolutely, I'm grateful to have someone like you in my life.

Character B: Me too, we shared so many moments of joy, sadness and other emotions.
Character A: It's true, our friendship has gone through a wide range of emotions and it is all the stronger for it.
Character B: Exactly, that's what makes our bond so special. And I look forward to sharing new moments together.
Character A: Me too, the future looks bright with you by my side.
Character B: Wait, I feel a pang of anger and sadness in you. What is happening ?
Character A: Actually, I'm a little frustrated because my parents don't seem very enthusiastic about me getting into college.
Character B: I understand your disappointment. It's hard when the people closest to us don't share our joy.
Character A: Yes, it pains me not to feel their support. I want them to be proud of me.
Character B: It's normal to feel sad and angry in this situation. But remember that you have other people who support you and believe in you, like me.
Character A: You're right, I shouldn't let their reaction affect my joy and determination.
Character B: Exactly, focus on the positive and encouraging people in your life. You deserve to be proud of yourself.
Character A: Thank you for your unconditional support. It means a lot to me.
Character B: I will always be there for you, no matter what emotions you are going through. Our friendship is solid.
Character A: And I'm grateful to have you by my side. Together, we will overcome all the emotions and challenges that will come our way.
Character B: That's exactly it. We are ready to face the future with strength and resilience.
Character A: Absolutely, our friendship is an invaluable source of support. Thank you for being there for me. I hate your fucking parents !
Character B: It's a pleasure to be your friend. We will go through all the emotions of life together. But please, get the fuck down you dirty piece of shit..


savait, et l'ayant psalmodié douze fois, il fit une
afin
douze
Paul. [7J Mais celuifois,
d'éprouver
prière
ci de son côté s'unissait avec ardeur à la prière, car, à ce
que je pense, il eût préféré paître des scorpions que de
vivre avec une femme adultère. Cependant, après les
douze prières, le soir étant avancé, ils s'assirent pour
ayant mangé l'un des biscuits,
manger. Or Antoine,
ne toucha pas à un autre. Mais le vieillard,
qui mangeait plus lentement, en était encore à son petit biscuit.
Antoine attendait qu'il eût fini, et il lui dit : « Mange,
» Paul lui dit :
petit père, encore un autre biscuit.
H Dans le cas où tu en manges, moi aussi ; mais toi ne
pas, je ne mange pas. » Antoine lui dit:
mangeant
qu'il

« Cela me suffit, car je suis moine. » [8] Paul lui dit :
« 11 me suffit également, car moi aussi je veux devenir
moine. » Il s'éveille de nouveau et fait douze prières et
psalmodie douze psaumes. 11 dort un peu du premier
au
sommeil, et de nouveau s'éveille pour psalmodier
milieu de la nuit jusqu'au jour. Alors, comme il voyait
que le vieillard l'avait suivi avec ardeur dans son régime,
il lui dit: « Si tu peux ainsi jour par jour,reste avec-moi.»
Paul lui dit: « En vérité, si parfois il arrive qu'il y ait
ce
quelque chose de plus, je ne sais pas ; car autrement,
» Antoine lui dit
que j'ai vu, je le fais bien dexlrement.
le (jour) après : « Voici que tu es devenu moine ».
"""

detecter_emotion(texte)
# Out:
# Character A: Hello, how are you today?
# Character B: It's going pretty well, I'm happy to see you!
# Character A: Great, I'm glad to hear that.
# By the way, I have news to tell you!
# Character B: Really?
# I'm curious, tell me everything!
# Character A: I've been accepted into my dream college!
# Character B: Wow, congratulations!
# I'm so proud of you, that's great news!
# Character A: Thank you!
# I am really excited and full of enthusiasm for this new adventure.
# Character B: I understand you, it must be a mixture of excitement and nervousness at the same time.
# Character A: Yes, exactly!
# I have so many things to prepare and organize.
# Character B: Don't worry, you are capable of meeting this challenge.
# I will be there to support you every step of the way.
# Character A: Thank you, it's comforting to know that I have your support.
# Character B: Of course, we are friends and I will be there to encourage you and help you when needed.
# ...

# %%
pip install text2emotion
# Out:
# ...
#      -------------------------------------- 57.8/57.8 kB 511.1 kB/s eta 0:00:00
# ...
#      -------------------------------------- 356.3/356.3 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for emoji: filename=emoji-2.5.1-py2.py3-none-any.whl size=351235 sha256=d6aa18472566a01d4ef634f230a2dc0fd38c5780f38dcc9d3aa30485ec09018c
#   Stored in directory: c:\users\lukas.pacalon\appdata\local\pip\cache\wheels\eb\20\3c\5fd1add8fe5078a1fccc478726dfe8558eca5bfa5ba5b28405
# Successfully built emoji
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install termcolor
# Out:
# ...
#
# ...

# %%
pip install emoji==1.7
# Out:
# ...
#      -------------------------------------- 175.4/175.4 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171059 sha256=6a04d9df540e6288e0483b20fdb22bd4420ae75ac1c923f55704f60879cdc01c
#   Stored in directory: c:\users\lukas.pacalon\appdata\local\pip\cache\wheels\37\b1\70\d87e2dddea71a019314970e3ea065b63e27b9be29e4a579b13
# Successfully built emoji
# ...
#   Attempting uninstall: emoji
#     Found existing installation: emoji 2.5.1
#     Uninstalling emoji-2.5.1:
#       Successfully uninstalled emoji-2.5.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\LUKAS.PACALON\AppData\Roaming\nltk_data...
# True

# %%
from text2emotion import get_emotion
from termcolor import colored

def afficher_texte_emotion(texte):
    phrases = texte.split('. ')
    
    for phrase in phrases:
        emotion = get_emotion(phrase)
        couleur = obtenir_couleur_emotion(emotion)
        texte_colore = colored(phrase, couleur)
        print(couleur)
        print(texte_colore)

def obtenir_couleur_emotion(emotion):
    if emotion == "Happy":
        return "green"
    elif emotion == "Angry":
        return "red"
    elif emotion == "Sad":
        return "blue"
    elif emotion == "Surprise":
        return "yellow"
    elif emotion == "Fear":
        return "magenta"
    else:
        return "white"

# Exemple d'utilisation
texte = "I am happy. I am Sad. I am suprised. I am angry! I am afraid"
afficher_texte_emotion(texte)
# Out:
# white
# I am happy
# white
# I am Sad
# white
# I am suprised
# white
# I am angry! I am afraid

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

def detecter_emotion(texte):
    sia = SentimentIntensityAnalyzer()
    phrases = nltk.sent_tokenize(texte)  # Diviser le texte en phrases
    
    for phrase in phrases:
        polarite = sia.polarity_scores(phrase)
        
        if polarite['compound'] >= 0.5:
            emotion = "\033[93m"  # Affichage en jaune pour la joie
        elif polarite['compound'] <= -0.5:
            emotion = "\033[94m"  # Affichage en bleu pour la tristesse
        elif polarite['compound'] > -0.5 and polarite['compound'] < 0.5:
            if polarite['neg'] > polarite['pos']:
                emotion = "\033[91m"  # Affichage en rouge pour la colère
            elif polarite['neg'] > polarite['neu']:
                emotion = "\033[95m"  # Affichage en violet pour la peur
            else:
                emotion = "\033[92m"  # Affichage en vert pour le neutre
        
        print(f"{emotion}{phrase}\033[0m")


# Exemple d'utilisation
texte = """
Character A: Hello, how are you today?
Character B: It's going pretty well, I'm happy to see you!
Character A: Great, me too.
"""

detecter_emotion(texte)
# Out:
# Character A: Hello, how are you today?
# Character B: It's going pretty well, I'm happy to see you!
# Character A: Great, me too.
